# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from plotnine import*
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("D:\\PG-DBDA\\python notes\\iris.csv")

# %%
df.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.describe(include='all')
# Out:
#         Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# count     150.000000   150.000000    150.000000   150.000000     150
# unique           NaN          NaN           NaN          NaN       3
# top              NaN          NaN           NaN          NaN  setosa
# freq             NaN          NaN           NaN          NaN      50
# mean        5.843333     3.057333      3.758000     1.199333     NaN
# std         0.828066     0.435866      1.765298     0.762238     NaN
# min         4.300000     2.000000      1.000000     0.100000     NaN
# 25%         5.100000     2.800000      1.600000     0.300000     NaN
# 50%         5.800000     3.000000      4.350000     1.300000     NaN
# 75%         6.400000     3.300000      5.100000     1.800000     NaN
# max         7.900000     4.400000      6.900000     2.500000     NaN

# %%
df.var()
# Out:
# Sepal.Length    0.685694
# Sepal.Width     0.189979
# Petal.Length    3.116278
# Petal.Width     0.581006
# dtype: float64

# %%
df.columns
# Out:
# Index(['Sepal.Length', 'Sepal.Width', 'Petal.Length', 'Petal.Width',
#        'Species'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Sepal.Length    float64
# Sepal.Width     float64
# Petal.Length    float64
# Petal.Width     float64
# Species          object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sepal.Length  150 non-null    float64
#  1   Sepal.Width   150 non-null    float64
#  2   Petal.Length  150 non-null    float64
#  3   Petal.Width   150 non-null    float64
#  4   Species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.isnull().sum()
# Out:
# Sepal.Length    0
# Sepal.Width     0
# Petal.Length    0
# Petal.Width     0
# Species         0
# dtype: int64

# %%
groupby_count1 = df.groupby(['Species']).count()

# %%
groupby_count1
# Out:
#             Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# Species
# setosa                50           50            50           50
# versicolor            50           50            50           50
# virginica             50           50            50           50

# %%
df.skew(axis = 0, skipna = True)
# Out:
# Sepal.Length    0.314911
# Sepal.Width     0.318966
# Petal.Length   -0.274884
# Petal.Width    -0.102967
# dtype: float64

# %%
df.skew(axis = 1, skipna = True)
# Out:
# 0      0.189328
# 1      0.404389
# 2      0.208782
# 3      0.120130
# 4      0.090753
#          ...
# 145    0.351514
# 146    0.256478
# 147    0.134795
# 148   -0.146244
# 149   -0.185387
# Length: 150, dtype: float64

# %%
correlations = df.corr()
print(correlations)
# Out:
#               Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# Sepal.Length      1.000000    -0.117570      0.871754     0.817941
# Sepal.Width      -0.117570     1.000000     -0.428440    -0.366126
# Petal.Length      0.871754    -0.428440      1.000000     0.962865
# Petal.Width       0.817941    -0.366126      0.962865     1.000000

# %%
df.cov()
# Out:
#               Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# Sepal.Length      0.685694    -0.042434      1.274315     0.516271
# Sepal.Width      -0.042434     0.189979     -0.329656    -0.121639
# Petal.Length      1.274315    -0.329656      3.116278     1.295609
# Petal.Width       0.516271    -0.121639      1.295609     0.581006

# %%
df.nunique()
# Out:
# Sepal.Length    35
# Sepal.Width     23
# Petal.Length    43
# Petal.Width     22
# Species          3
# dtype: int64

# %%
s_size=df['Sepal.Length']*df['Sepal.Width']
df.insert(1,'sepal_size',s_size)

# %%
s_size
# Out:
# 0      17.85
# 1      14.70
# 2      15.04
# 3      14.26
# 4      18.00
#        ...
# 145    20.10
# 146    15.75
# 147    19.50
# 148    21.08
# 149    17.70
# Length: 150, dtype: float64

# %%
df
# Out:
#      Sepal.Length  sepal_size  Sepal.Width  Petal.Length  Petal.Width  \
# 0             5.1       17.85          3.5           1.4          0.2
# 1             4.9       14.70          3.0           1.4          0.2
# 2             4.7       15.04          3.2           1.3          0.2
# 3             4.6       14.26          3.1           1.5          0.2
# 4             5.0       18.00          3.6           1.4          0.2
# ..            ...         ...          ...           ...          ...
# 145           6.7       20.10          3.0           5.2          2.3
# 146           6.3       15.75          2.5           5.0          1.9
# 147           6.5       19.50          3.0           5.2          2.0
# 148           6.2       21.08          3.4           5.4          2.3
# 149           5.9       17.70          3.0           5.1          1.8
#
#        Species
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# ...

# %%
p_size=df['Petal.Length']*df['Petal.Width']
df.insert(2,'petal_size',p_size)

# %%
sns.boxplot(df['Sepal.Width'])
# Out:
# <AxesSubplot:xlabel='Sepal.Width'>

# %%
print(np.where(df['Sepal.Width']>4.05))
# Out:
# (array([15, 32, 33], dtype=int64),)

# %%
sns.boxplot(df['Sepal.Length'])
# Out:
# <AxesSubplot:xlabel='Sepal.Length'>

# %%
sns.boxplot(df['Petal.Width'])
# Out:
# <AxesSubplot:xlabel='Petal.Width'>

# %%
sns.boxplot(df['Petal.Length'])
# Out:
# <AxesSubplot:xlabel='Petal.Length'>

# %%
Q1 = np.percentile(df['Sepal.Width'], 25,
                   interpolation = 'midpoint')
 
Q3 = np.percentile(df['Sepal.Width'], 75,
                   interpolation = 'midpoint')
IQR = Q3 - Q1

# %%
IQR
# Out:
# 0.5

# %%
(Q3+1.5*IQR) #upper bound
# Out:
# 4.05

# %%
(Q1-1.5*IQR)#lower bound
# Out:
# 2.05

# %%
upper = df['Sepal.Width'] >= (Q3+1.5*IQR)
 
print("Upper bound:",upper)
print(np.where(upper))
 

lower = df['Sepal.Width'] <= (Q1-1.5*IQR)
print("Lower bound:", lower)
print(np.where(lower))
# Out:
# Upper bound: 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Name: Sepal.Width, Length: 150, dtype: bool
# (array([15, 32, 33], dtype=int64),)
# Lower bound: 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Name: Sepal.Width, Length: 150, dtype: bool
# (array([60], dtype=int64),)

# %%
from scipy import stats
z = np.abs(stats.zscore(df['Sepal.Width']))
print(z)
# Out:
# 0      1.019004
# 1      0.131979
# 2      0.328414
# 3      0.098217
# 4      1.249201
#          ...
# 145    0.131979
# 146    1.282963
# 147    0.131979
# 148    0.788808
# 149    0.131979
# Name: Sepal.Width, Length: 150, dtype: float64

# %%
threshold = 3
 
# Position of the outlier
print(np.where(z > 3))
# Out:
# (array([15], dtype=int64),)

# %%
ax = sns.stripplot(x='Species', y='Sepal.Length', data=df)

# %%
ax = sns.swarmplot(x='Species', y='Sepal.Length', data=df)

# %%
sns.barplot(x ='Species', y ='Sepal.Length', data = df,
            palette ='plasma')
# Out:
# <AxesSubplot:xlabel='Species', ylabel='Sepal.Length'>

# %%
sns.countplot(x ='Species', data = df)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='count'>

# %% [markdown]
# sns.boxplot(x='Sepal.Length', y='Sepal.Width', data=df, hue='Species')

# %%
sns.violinplot(x='Species',y='Petal.Length',data=df)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='Petal.Length'>

# %%
sns.violinplot(x='Species',y='Sepal.Length',data=df)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='Sepal.Length'>

# %%
sns.stripplot(x='Sepal.Length', y='Sepal.Width', data=df,jitter = False, hue='Species', dodge=True)
# Out:
# <AxesSubplot:xlabel='Sepal.Length', ylabel='Sepal.Width'>

# %%
(ggplot(df,aes(x='Species',y='Sepal.Length'))+geom_point())
# Out:
# <ggplot: (127838327534)>

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
ax = plt.gca()
df.plot( x = 'Species' , y = 'Sepal.Width', ax = ax )
df.plot( x = 'Species' , y = 'Petal.Width' , ax = ax )
# Out:
# <AxesSubplot:xlabel='Species'>

# %%
plt.figure(figsize=(4,2))
sns.distplot(df['sepal_size'])
plt.show()

# %%
plt.figure(figsize=(4,2))
sns.distplot(df['petal_size'])
plt.show()

# %%
plt.hist(df.Species)
plt.show()

# %%
columns = ['Sepal.Length' , 'Sepal.Width' , 'Petal.Length' , 'Petal.Width']
fig, ax = plt.subplots(4, figsize = (7,17))
for i in range(len(columns)) :
    ax[i].hist(df[columns[i]])
    ax[i].set_title(columns[i])
plt.show()

# %%
sns.heatmap(df.corr(), annot = True)

plt.show()

# %%
sns.pairplot(df,hue='Species')
plt.show()

# %%
plt.figure(figsize=(18,5))
sns.displot(df)
plt.title('Distribution', fontsize='xx-large')
# Out:
# Text(0.5, 1.0, 'Distribution')

# %%
colors = {'setosa':'red','virginica' : 'blue', 'versicolor' : 'green'}
plt.scatter(df[columns[2]],df[columns[3]],
           c=df['Species'].map(colors))
plt.xlabel(columns[2])
plt.ylabel(columns[3])
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
df
# Out:
#      Sepal.Length  sepal_size  petal_size  Sepal.Width  Petal.Length  \
# 0             5.1       17.85        0.28          3.5           1.4
# 1             4.9       14.70        0.28          3.0           1.4
# 2             4.7       15.04        0.26          3.2           1.3
# 3             4.6       14.26        0.30          3.1           1.5
# 4             5.0       18.00        0.28          3.6           1.4
# ..            ...         ...         ...          ...           ...
# 145           6.7       20.10       11.96          3.0           5.2
# 146           6.3       15.75        9.50          2.5           5.0
# 147           6.5       19.50       10.40          3.0           5.2
# 148           6.2       21.08       12.42          3.4           5.4
# 149           5.9       17.70        9.18          3.0           5.1
#
#      Petal.Width    Species
# 0            0.2     setosa
# 1            0.2     setosa
# 2            0.2     setosa
# ...

# %%
X = df.iloc[:, [0,5]].values
y = df.iloc[:, -1].values

# %%
X
# Out:
# array([[5.1, 0.2],
#        [4.9, 0.2],
#        [4.7, 0.2],
#        [4.6, 0.2],
#        [5. , 0.2],
#        [5.4, 0.4],
#        [4.6, 0.3],
#        [5. , 0.2],
#        [4.4, 0.2],
#        [4.9, 0.1],
#        [5.4, 0.2],
#        [4.8, 0.2],
#        [4.8, 0.1],
#        [4.3, 0.1],
#        [5.8, 0.2],
#        [5.7, 0.4],
#        [5.4, 0.4],
#        [5.1, 0.3],
#        [5.7, 0.3],
#        [5.1, 0.3],
#        [5.4, 0.2],
#        [5.1, 0.4],
#        [4.6, 0.2],
#        [5.1, 0.5],
#        [4.8, 0.2],
#        [5. , 0.2],
#        [5. , 0.4],
#        [5.2, 0.2],
#        [5.2, 0.2],
#        [4.7, 0.2],
#        [4.8, 0.2],
#        [5.4, 0.4],
#        [5.2, 0.1],
#        [5.5, 0.2],
#        [4.9, 0.2],
#        [5. , 0.2],
#        [5.5, 0.2],
#        [4.9, 0.1],
#        [4.4, 0.2],
#        [5.1, 0.2],
#        [5. , 0.3],
#        [4.5, 0.3],
#        [4.4, 0.2],
#        [5. , 0.6],
#        [5.1, 0.4],
#        [4.8, 0.3],
#        [5.1, 0.2],
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
X_train
# Out:
# array([[-0.04101289,  0.03418963],
#        [-1.44716902, -1.15693283],
#        [ 1.01360421,  1.75469984],
#        [ 0.5448855 ,  0.43123045],
#        [ 0.89642453,  0.29888351],
#        [ 1.5995026 ,  0.56357738],
#        [-0.27537224, -0.09815731],
#        [-0.27537224,  0.16653657],
#        [-0.15819256, -1.15693283],
#        [ 2.18540099,  1.49000596],
#        [-0.86127063, -0.09815731],
#        [ 1.36514324,  0.29888351],
#        [-0.86127063, -1.02458589],
#        [-0.97845031, -0.23050425],
#        [-1.32998934, -1.28927977],
#        [-1.09562999, -1.42162671],
#        [-0.39255192, -0.09815731],
#        [ 0.31052615,  0.03418963],
#        [ 1.83386196,  0.9606182 ],
#        [-0.5097316 , -1.28927977],
#        [-0.27537224,  1.09296514],
#        [-1.68152837, -1.28927977],
#        [-0.15819256,  0.16653657],
#        [ 0.77924486,  0.43123045],
#        [-0.5097316 , -1.02458589],
#        [ 0.19334647,  0.56357738],
#        [-1.21280966, -1.15693283],
# ...

# %%
X_train.var()
# Out:
# 1.0000000000000002

# %%
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = classifier.predict(X_test)
print(y_pred)
# Out:
# ['setosa' 'virginica' 'versicolor' 'versicolor' 'virginica' 'virginica'
#  'virginica' 'setosa' 'versicolor' 'setosa' 'virginica' 'versicolor'
#  'versicolor' 'setosa' 'setosa' 'virginica' 'virginica' 'virginica'
#  'versicolor' 'virginica' 'versicolor' 'virginica' 'setosa' 'versicolor'
#  'setosa' 'setosa' 'versicolor' 'setosa' 'virginica' 'versicolor']

# %%
y_pred_proba = classifier.predict_proba(X_test)
print(y_pred_proba)
# Out:
# [[8.84186645e-001 1.15809952e-001 3.40272249e-006]
#  [2.30564917e-073 4.57922061e-002 9.54207794e-001]
#  [1.11313131e-015 9.99697633e-001 3.02366944e-004]
#  [1.14233899e-043 9.40621596e-001 5.93784042e-002]
#  [2.09251758e-125 3.34698033e-007 9.99999665e-001]
#  [9.24194257e-061 1.31045823e-001 8.68954177e-001]
#  [8.59006057e-137 2.60425684e-008 9.99999974e-001]
#  [9.99999992e-001 8.26333297e-009 8.07457031e-013]
#  [5.98521237e-016 9.99636510e-001 3.63490148e-004]
#  [9.99999999e-001 8.45243244e-010 4.47312981e-014]
#  [1.58750054e-116 1.23414512e-006 9.99998766e-001]
#  [4.47690345e-045 8.58021005e-001 1.41978995e-001]
#  [2.61764970e-025 9.98647120e-001 1.35288014e-003]
#  [9.99999998e-001 2.23760642e-009 1.52032843e-013]
#  [9.99999999e-001 5.31410511e-010 2.53566604e-014]
#  [5.83362132e-115 2.90235748e-006 9.99997098e-001]
#  [7.35326860e-069 2.90307756e-002 9.70969224e-001]
#  [7.67834722e-067 8.35576636e-002 9.16442336e-001]
# ...

# %%
numbers = range(4, -1, -1)    
print(list(numbers))
# Out:
# [4, 3, 2, 1, 0]

# %%
numbers = range(4, 1, -1)    
print(list(numbers))
# Out:
# [4, 3, 2]

# %%
import math
dir(math)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']
